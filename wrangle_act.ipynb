# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
#importing the relevant libraries
import pandas as pd 
import requests
import os 
import tweepy
import time
import json
import seaborn as sns 
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#loading the WeRateDogs Twitter archive data

archive = pd.read_csv('twitter_archive_enhanced.csv')
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
#using requests library to download the tweet image prediciton data set
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
with open('image_predictions.tsv', mode = 'wb') as file:
    file.write(response.content)
image_predictions = pd.read_csv('image_predictions.tsv', sep = '\t')
image_predictions
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
#Using tweepy to query additional data from twitter's API

consumer_key = 'This was removed'
consumer_secret = 'This was removed'
access_token = 'This was removed'
access_secret = 'This was removed'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
start = time.time()
with open('getstatus_error.txt', 'w') as errfile: 
    valid_ids = 0
    err_ids = 0
    tweet_ids = archive['tweet_id']
    with open('tweet_json.txt', 'w', encoding='utf-8') as outfile:
        for i, tweet_id in tweet_ids.iteritems():
            try:
                print("%s# %s" % (str(i+1), tweet_id))
                # Get tweet data using Twitter API
                tweet = api.get_status(tweet_id, tweet_mode='extended')
                json_content = tweet._json
                
                # Write each tweet's JSON data to its own line in a file
                json.dump(json_content, outfile)
                outfile.write('\n')
                valid_ids += 1
            except tweepy.TweepError as e:
                err_ids += 1
                err_str = []
                err_str.append(str(tweet_id))
                err_str.append(': ')
                err_str.append(e.response.json()['errors'][0]['message'])
                err_str.append('\n')
                errfile.write(''.join(err_str))
                print(''.join(err_str))
                continue
        print("%s %s" % ('Valid tweets:', valid_ids))
        print("%s %s" % ('Error tweets:', err_ids))
        
end = time.time()
time_taken = end - start
print(time_taken)
# Out:
# 1# 892420643555336193
# 2# 892177421306343426
# 3# 891815181378084864
# 4# 891689557279858688
# 5# 891327558926688256
# 6# 891087950875897856
# 7# 890971913173991426
# 8# 890729181411237888
# 9# 890609185150312448
# 10# 890240255349198849
# 11# 890006608113172480
# 12# 889880896479866881
# 13# 889665388333682689
# 14# 889638837579907072
# 15# 889531135344209921
# 16# 889278841981685760
# 17# 888917238123831296
# 18# 888804989199671297
# 19# 888554962724278272
# 20# 888202515573088257
# 888202515573088257: No status found with that ID.
#
# 21# 888078434458587136
# 22# 887705289381826560
# 23# 887517139158093824
# 24# 887473957103951883
# 25# 887343217045368832
# 26# 887101392804085760
# 27# 886983233522544640
# 28# 886736880519319552
# 29# 886680336477933568
# 30# 886366144734445568
# 31# 886267009285017600
# 32# 886258384151887873
# 33# 886054160059072513
# 34# 885984800019947520
# 35# 885528943205470208
# 36# 885518971528720385
# 37# 885311592912609280
# 38# 885167619883638784
# ...

# %%
#Checking the number of minutes taken to query the data on Twiitter's API
time_taken/60
# Out:
# 32.086540548006695

# %%
len(tweet_ids)
# Out:
# 2356

# %%
# List of dictionaries to read tweet's JSON data line by line and later convert to a DataFrame
df_list = []
with open('tweet_json.txt', 'r') as json_file:
    for line in json_file:
        status = json.loads(line)
        
        # Append to list of dictionaries
        df_list.append({'tweet_id': status['id'],
                        'retweet_count': status['retweet_count'],
                        'favorite_count': status['favorite_count'],
                       })

# Create a DataFrame with tweet ID, retweet count, favorite count and display_text_range
tweets_json = pd.DataFrame(df_list, columns = ['tweet_id', 'retweet_count', 'favorite_count'])

# %%
tweets_json
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           6944           33574
# 1     892177421306343426           5247           29127
# 2     891815181378084864           3459           21916
# 3     891689557279858688           7156           36640
# 4     891327558926688256           7694           35030
# 5     891087950875897856           2571           17682
# 6     890971913173991426           1640           10289
# 7     890729181411237888          15632           56451
# 8     890609185150312448           3596           24355
# 9     890240255349198849           6047           27745
# 10    890006608113172480           6094           26857
# 11    889880896479866881           4124           24402
# 12    889665388333682689           8271           41722
# 13    889638837579907072           3686           23492
# 14    889531135344209921           1869           13269
# 15    889278841981685760           4404           21931
# ...

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# Visual Assessment

# %%
#Visually assessing the archive data set 
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
#Visually assessing the image_predictions data set
image_predictions
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
#visually assessing the tweets_json data set
tweets_json
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           6944           33574
# 1     892177421306343426           5247           29127
# 2     891815181378084864           3459           21916
# 3     891689557279858688           7156           36640
# 4     891327558926688256           7694           35030
# 5     891087950875897856           2571           17682
# 6     890971913173991426           1640           10289
# 7     890729181411237888          15632           56451
# 8     890609185150312448           3596           24355
# 9     890240255349198849           6047           27745
# 10    890006608113172480           6094           26857
# 11    889880896479866881           4124           24402
# 12    889665388333682689           8271           41722
# 13    889638837579907072           3686           23492
# 14    889531135344209921           1869           13269
# 15    889278841981685760           4404           21931
# ...

# %% [markdown]
# Programmatic Assessment

# %%
#Progmatically Asessing the archive data set

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
#checking for rows that contains retweet
archive[archive['text'].str.startswith('RT')]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 101   872668790621863937                    NaN                  NaN
# 109   871166179821445120                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# ...

# %%
# Checking for tweet replies in the dataset
archive[archive.in_reply_to_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 149   863079547188785154           6.671522e+17         4.196984e+09
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 184   856526610513747968           8.558181e+17         4.196984e+09
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# ...

# %%
#checking for duplicated tweet_id 
archive.tweet_id.duplicated().sum()
# Out:
# 0

# %%
#Programmatically assessing the image_predicitions data set
image_predictions.shape
# Out:
# (2075, 12)

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.tweet_id.duplicated().sum()
# Out:
# 0

# %%
#Programmatically assessing the tweets_json data set

tweets_json.shape
# Out:
# (2325, 3)

# %%
tweets_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2325 entries, 0 to 2324
# Data columns (total 3 columns):
# tweet_id          2325 non-null int64
# retweet_count     2325 non-null int64
# favorite_count    2325 non-null int64
# dtypes: int64(3)
# memory usage: 54.6 KB

# %% [markdown]
# ### Quality issues
# 1. tweet_id is of integer data type
#
# 2. The dataset contains some retweet data
#
# 3. The name column for animals includes articles such as "a", "an" and "the"
#
# 4. The timestamp has +0000 after the seconds
#
# 5. rating_numerator and rating_denominator is int dtype instead of object
#
# 6. Some of the tweets are replies and are not original tweets
#
# 7. Timestamp is object data type instead of datetime
#
# 8. in_reply_to_status_id is of float datatype

# %% [markdown]
# ### Tidiness issues
# 1. The three data sets should be merged into one
#
# 2. Columns doggo, floofer, pupper, and puppo should me merged into a single column

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
archive_copy = archive.copy()
image_predictions_copy = image_predictions.copy()
tweets_json_copy = tweets_json.copy()

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define: `tweet_id` should be of object dtype in all data sets and not integer

# %% [markdown]
# #### Code

# %%
#convert the datatype of tweet_id to string
archive_copy.tweet_id = archive_copy.tweet_id.astype(str)
image_predictions_copy.tweet_id = image_predictions_copy.tweet_id.astype(str)
tweets_json_copy.tweet_id = tweets_json_copy.tweet_id.astype(str)

# %% [markdown]
# #### Test

# %%
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null object
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
image_predictions_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
tweets_json_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2325 entries, 0 to 2324
# Data columns (total 3 columns):
# tweet_id          2325 non-null object
# retweet_count     2325 non-null int64
# favorite_count    2325 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 54.6+ KB

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define
#
# removing retweets from the data set as we are required to have just original tweets

# %% [markdown]
# #### Code

# %%
#Storing all retweets in a new variable and dropping those rows.
retweets = archive_copy[archive_copy['text'].str.startswith('RT')].index
archive_copy.drop(retweets, inplace = True)

# %% [markdown]
# #### Test

# %%
archive_copy.shape
# Out:
# (2173, 17)

# %%
#Confirming that there are no more retweets in the text column
archive_copy[archive_copy['text'].str.startswith('RT')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Define
#
# The timestamp has +0000 after the seconds

# %% [markdown]
# #### Code

# %%
archive_copy.timestamp = archive_copy.timestamp.str.replace(' +0000', '', regex = False)

# %% [markdown]
# #### Test

# %%
archive_copy.timestamp
# Out:
# 0       2017-08-01 16:23:56
# 1       2017-08-01 00:17:27
# 2       2017-07-31 00:18:03
# 3       2017-07-30 15:58:51
# 4       2017-07-29 16:00:24
# 5       2017-07-29 00:08:17
# 6       2017-07-28 16:27:12
# 7       2017-07-28 00:22:40
# 8       2017-07-27 16:25:51
# 9       2017-07-26 15:59:51
# 10      2017-07-26 00:31:25
# 11      2017-07-25 16:11:53
# 12      2017-07-25 01:55:32
# 13      2017-07-25 00:10:02
# 14      2017-07-24 17:02:04
# 15      2017-07-24 00:19:32
# 16      2017-07-23 00:22:39
# 17      2017-07-22 16:56:37
# 18      2017-07-22 00:23:06
# 20      2017-07-20 16:49:33
# 21      2017-07-19 16:06:48
# 22      2017-07-19 03:39:09
# 23      2017-07-19 00:47:34
# 24      2017-07-18 16:08:03
# 25      2017-07-18 00:07:08
# 26      2017-07-17 16:17:36
# 27      2017-07-16 23:58:41
# 28      2017-07-16 20:14:00
# 29      2017-07-15 23:25:31
# 30      2017-07-15 16:51:35
#                ...
# 2326    2015-11-17 00:24:19
# 2327    2015-11-17 00:06:54
# ...

# %% [markdown]
# ### Issue 4:

# %% [markdown]
# #### Define:
#
# time_stamp is of object data type as against datetime

# %% [markdown]
# #### Code

# %%
#Converting the data type from oject to datetime
archive_copy.timestamp = archive_copy.timestamp.astype('datetime64')

# %% [markdown]
# #### Test

# %%
archive_copy['timestamp'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Issue 5:

# %% [markdown]
# #### Define
#
# replacing articles such as a, an, the etc with None

# %% [markdown]
# #### Code

# %%
archive_copy.name.replace("a", value = 'None', inplace=True )
archive_copy.name.replace("the", value = 'None', inplace=True )
archive_copy.name.replace("very", value = 'None', inplace=True )
archive_copy.name.replace("not", value = 'None', inplace=True )
archive_copy.name.replace("an", value = 'None', inplace=True )
archive_copy.name.replace("a", value = 'None', inplace=True )

# %% [markdown]
# #### Test

# %%
archive_copy.name.value_counts()
# Out:
# None        753
# Charlie      11
# Lucy         11
# Cooper       10
# Oliver       10
# Tucker        9
# Penny         9
# Winston       8
# Lola          8
# Sadie         8
# Toby          7
# Daisy         7
# Jax           6
# Oscar         6
# Stanley       6
# Koda          6
# Bo            6
# Bella         6
# Bailey        6
# Milo          5
# Rusty         5
# Buddy         5
# Scout         5
# Bentley       5
# Louis         5
# Dave          5
# Leo           5
# Chester       5
# Larry         4
# Sophie        4
#            ...
# Goose         1
# Sobe          1
# Dixie         1
# Bodie         1
# Tebow         1
# Lilly         1
# Moreton       1
# Bronte        1
# Nigel         1
# Lucky         1
# Pablo         1
# Ole           1
# Klein         1
# Erik          1
# Huxley        1
# Eevee         1
# Kallie        1
# Marvin        1
# Laela         1
# Bowie         1
# Shadoe        1
# Leonidas      1
# Spark         1
# Zoe           1
# ...

# %% [markdown]
# ### Issue 6:

# %% [markdown]
# #### Define
#
# Some of the tweets are replies and are not original tweets

# %% [markdown]
# #### Code

# %%
# Assigning the tweet replies to a variable and dropping those rows with values
replies = archive_copy[archive_copy.in_reply_to_status_id.notnull()].index

archive_copy.drop(replies, inplace = True)

# %% [markdown]
# #### Test

# %%
archive_copy[archive_copy.in_reply_to_status_id.notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
archive_copy.shape
# Out:
# (2095, 17)

# %% [markdown]
# ### Issue 7:

# %% [markdown]
# #### Define
# `in_reply_to_status_id` is of float datatype

# %% [markdown]
# #### Code

# %%
#Converting the dtype from float to object
archive_copy.in_reply_to_status_id = archive_copy.in_reply_to_status_id.astype(str)

# %% [markdown]
# #### Test

# %%
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2095 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2095 non-null object
# in_reply_to_status_id         2095 non-null object
# in_reply_to_user_id           0 non-null float64
# timestamp                     2095 non-null datetime64[ns]
# source                        2095 non-null object
# text                          2095 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2092 non-null object
# rating_numerator              2095 non-null int64
# rating_denominator            2095 non-null int64
# name                          2095 non-null object
# doggo                         2095 non-null object
# floofer                       2095 non-null object
# pupper                        2095 non-null object
# ...

# %% [markdown]
# ### Issue 8:

# %% [markdown]
# #### Define
# `rating_numerator` and `rating_denominator` are of integer dtype as against float dtype

# %% [markdown]
# #### Code

# %%
archive_copy.rating_numerator = archive_copy.rating_numerator.astype(str)
archive_copy.rating_denominator = archive_copy.rating_denominator.astype(str)

# %% [markdown]
# #### Test

# %%
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2095 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2095 non-null object
# in_reply_to_status_id         2095 non-null object
# in_reply_to_user_id           0 non-null float64
# timestamp                     2095 non-null datetime64[ns]
# source                        2095 non-null object
# text                          2095 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2092 non-null object
# rating_numerator              2095 non-null object
# rating_denominator            2095 non-null object
# name                          2095 non-null object
# doggo                         2095 non-null object
# floofer                       2095 non-null object
# pupper                        2095 non-null object
# ...

# %% [markdown]
# ### Issue 9:

# %% [markdown]
# #### Define
#
# Columns doggo, floofer, pupper, and puppo should me merged into a single column, we will be using the melt function to do this

# %% [markdown]
# #### Code

# %%
# Replace the null values in the corresponding empty columns for each record with nothing
archive_copy.doggo.replace('None', '', inplace=True)
archive_copy.floofer.replace('None', '', inplace=True)
archive_copy.pupper.replace('None', '', inplace=True)
archive_copy.puppo.replace('None', '', inplace=True)

# merge all columns into one
archive_copy['dogs_stage'] = archive_copy.doggo + archive_copy.floofer + archive_copy.pupper + archive_copy.puppo

#drop unwanted columns 
archive_copy.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis = 1, inplace = True)

# %%
archive_copy.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'dogs_stage'],
#       dtype='object')

# %%
archive_copy.head()
# Out:
#              tweet_id in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                   nan                  NaN
# 1  892177421306343426                   nan                  NaN
# 2  891815181378084864                   nan                  NaN
# 3  891689557279858688                   nan                  NaN
# 4  891327558926688256                   nan                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# ...

# %%
archive_copy.dogs_stage.value_counts()
# Out:
#                 1759
# pupper           221
# doggo             72
# puppo             23
# floofer            9
# doggopupper        9
# doggofloofer       1
# doggopuppo         1
# Name: dogs_stage, dtype: int64

# %% [markdown]
# ### Issue 10:

# %% [markdown]
# #### Define
#
# The three data sets should be merged into one

# %% [markdown]
# #### Code

# %%
#merge the image_predictions_copy and archive_var data sets first and then merge the result with the tweets_json_copy
merged_table = pd.merge(archive_copy, image_predictions_copy, on ='tweet_id')
df_clean = pd.merge(merged_table, tweets_json_copy, on = 'tweet_id')

# %%
df_clean.sample(5)
# Out:
#                 tweet_id in_reply_to_status_id  in_reply_to_user_id  \
# 712   750026558547456000                   nan                  NaN
# 655   758041019896193024                   nan                  NaN
# 467   792394556390137856                   nan                  NaN
# 210   839239871831150596                   nan                  NaN
# 1721  670452855871037440                   nan                  NaN
#
#                timestamp                                             source  \
# 712  2016-07-04 18:00:41  <a href="https://about.twitter.com/products/tw...
# 655  2016-07-26 20:47:17  <a href="http://twitter.com/download/iphone" r...
# 467  2016-10-29 15:55:58  <a href="http://twitter.com/download/iphone" r...
# 210  2017-03-07 22:22:32  <a href="http://twitter.com/download/iphone" r...
# 1721 2015-11-28 04:03:11  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# ...

# %%
#Dropping columns with null values in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id
df_clean.drop(columns = ['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'],  axis = 1, inplace = True)
df_clean
# Out:
#                 tweet_id           timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56
# 1     892177421306343426 2017-08-01 00:17:27
# 2     891815181378084864 2017-07-31 00:18:03
# 3     891689557279858688 2017-07-30 15:58:51
# 4     891327558926688256 2017-07-29 16:00:24
# 5     891087950875897856 2017-07-29 00:08:17
# 6     890971913173991426 2017-07-28 16:27:12
# 7     890729181411237888 2017-07-28 00:22:40
# 8     890609185150312448 2017-07-27 16:25:51
# 9     890240255349198849 2017-07-26 15:59:51
# 10    890006608113172480 2017-07-26 00:31:25
# 11    889880896479866881 2017-07-25 16:11:53
# 12    889665388333682689 2017-07-25 01:55:32
# 13    889638837579907072 2017-07-25 00:10:02
# 14    889531135344209921 2017-07-24 17:02:04
# 15    889278841981685760 2017-07-24 00:19:32
# 16    888917238123831296 2017-07-23 00:22:39
# 17    888804989199671297 2017-07-22 16:56:37
# 18    888554962724278272 2017-07-22 00:23:06
# 19    888078434458587136 2017-07-20 16:49:33
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1962 entries, 0 to 1961
# Data columns (total 22 columns):
# tweet_id              1962 non-null object
# timestamp             1962 non-null datetime64[ns]
# source                1962 non-null object
# text                  1962 non-null object
# expanded_urls         1962 non-null object
# rating_numerator      1962 non-null object
# rating_denominator    1962 non-null object
# name                  1962 non-null object
# dogs_stage            1962 non-null object
# jpg_url               1962 non-null object
# img_num               1962 non-null int64
# p1                    1962 non-null object
# p1_conf               1962 non-null float64
# p1_dog                1962 non-null bool
# p2                    1962 non-null object
# p2_conf               1962 non-null float64
# p2_dog                1962 non-null bool
# p3                    1962 non-null object
# p3_conf               1962 non-null float64
# ...

# %%
df_clean.shape
# Out:
# (1962, 22)

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
df_clean.to_csv('twitter_archive_master.csv')

# %%
df_clean.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %% [markdown]
# Analysing the dog stage with the highest value

# %%
#creating a dataframe for dogs that are not equal to blank
df_dogs = df_clean[df_clean['dogs_stage'] != '']
df_dogs.dogs_stage.value_counts()
# Out:
# pupper          201
# doggo            62
# puppo            22
# doggopupper       8
# floofer           7
# doggopuppo        1
# doggofloofer      1
# Name: dogs_stage, dtype: int64

# %%
#plotting the bar chart

plt.bar(x= df_dogs['dogs_stage'].value_counts().index, height= df_dogs.dogs_stage.value_counts().values)
plt.title('Analysis of Dog Stages')
plt.xlabel('Dog Stages')
plt.ylabel('Number of Dogs');

ax = plt.gca()
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right');

# %%
#plotting a scatter plot showing the correlation between retweet_count and favorite_count
df_clean.plot.scatter(x = 'retweet_count', y = 'favorite_count')
plt.title('Correlation between retweet_count and favorite_count')
plt.xlabel('Retweet_count')
plt.ylabel('Favorite_count');

# %% [markdown]
# ### Insights:
# 1. Pupper is the most common dog stage
#
# 2. Doggoflopper is the least occuring dog stage
#
# 3. There is a positive correlation between Retweet_count and Favorite_count

# %% [markdown]
# ### Visualization

# %%
#Image with the highest tweet Image Number

df_img = df_clean.img_num.value_counts()

df_img.plot.bar()
plt.title('Tweet Count By Image Number')
plt.xlabel('Tweet Count')
plt.ylabel('Image Number');
